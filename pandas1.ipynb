# %% [markdown]
# Pandas part 2

# %%
import pandas as pd

# %%
pd.__version__
# Out:
# '2.3.2'

# %%
df=pd.read_csv(r'D:\Data Science\generated_country_data.csv')
df
# Out:
#     Unnamed: 0  CountryName CountryCode  BirthRate  InternetUsers  \
# 0            0    Country_1       CT001     46.605         26.355
# 1            1    Country_2       CT002      6.488         14.267
# 2            2    Country_3       CT003     18.663         50.560
# 3            3    Country_4       CT004     36.708         24.956
# 4            4    Country_5       CT005     29.782         26.785
# ..         ...          ...         ...        ...            ...
# 95          95   Country_96       CT096     19.964         24.437
# 96          96   Country_97       CT097     20.020         93.442
# 97          97   Country_98       CT098      5.971         57.543
# 98          98   Country_99       CT099     35.620         91.722
# 99          99  Country_100       CT100     47.923         92.718
#
#             IncomeGroup
# 0            Low income
# 1   Upper middle income
# 2   Upper middle income
# 3   Upper middle income
# 4   Lower middle income
# ...

# %%
df.columns
# Out:
# Index(['Unnamed: 0', 'CountryName', 'CountryCode', 'BirthRate',
#        'InternetUsers', 'IncomeGroup'],
#       dtype='object')

# %%
df.columns=['a','b','c','d','e','f'] # changeing the columns name... (Note: While changing columns names we should change all names of columns )
df.columns
# Out:
# Index(['a', 'b', 'c', 'd', 'e', 'f'], dtype='object')

# %%
df.head(2)
# Out:
#    a          b      c       d       e                    f
# 0  0  Country_1  CT001  46.605  26.355           Low income
# 1  1  Country_2  CT002   6.488  14.267  Upper middle income

# %%
df.columns
# Out:
# Index(['a', 'b', 'c', 'd', 'e', 'f'], dtype='object')

# %%
df.columns=['Unnamed: 0', 'CountryName', 'CountryCode', 'BirthRate','InternetUsers', 'IncomeGroup']
df.columns
# Out:
# Index(['Unnamed: 0', 'CountryName', 'CountryCode', 'BirthRate',
#        'InternetUsers', 'IncomeGroup'],
#       dtype='object')

# %%
df.head(2)
# Out:
#    Unnamed: 0 CountryName CountryCode  BirthRate  InternetUsers  \
# 0           0   Country_1       CT001     46.605         26.355
# 1           1   Country_2       CT002      6.488         14.267
#
#            IncomeGroup
# 0           Low income
# 1  Upper middle income

# %%
df_categirical =df[['CountryName', 'CountryCode','IncomeGroup']] #Store categirical [text] data.
df_categirical.head()
# Out:
#   CountryName CountryCode          IncomeGroup
# 0   Country_1       CT001           Low income
# 1   Country_2       CT002  Upper middle income
# 2   Country_3       CT003  Upper middle income
# 3   Country_4       CT004  Upper middle income
# 4   Country_5       CT005  Lower middle income

# %%
df_categirical.describe()
# Out:
#        CountryName CountryCode          IncomeGroup
# count          100         100                  100
# unique         100         100                    4
# top      Country_1       CT001  Upper middle income
# freq             1           1                   27

# %%
['CountryName','BirthRate']
# Out:
# ['CountryName', 'BirthRate']

# %%
df[['CountryName','BirthRate']]
# Out:
#     CountryName  BirthRate
# 0     Country_1     46.605
# 1     Country_2      6.488
# 2     Country_3     18.663
# 3     Country_4     36.708
# 4     Country_5     29.782
# ..          ...        ...
# 95   Country_96     19.964
# 96   Country_97     20.020
# 97   Country_98      5.971
# 98   Country_99     35.620
# 99  Country_100     47.923
#
# [100 rows x 2 columns]

# %%
#Mathematical Operations
df.BirthRate * df.InternetUsers #multipling 2 columns BirthRate and InternetUsers
# Out:
# 0     1228.274775
# 1       92.564296
# 2      943.601280
# 3      916.084848
# 4      797.710870
#          ...
# 95     487.860268
# 96    1870.708840
# 97     343.589253
# 98    3267.137640
# 99    4443.324714
# Length: 100, dtype: float64

# %%
df['myCal'] = df.BirthRate * df.InternetUsers #multipling 2 columns BirthRate and InternetUsers creating a new column

df[['myCal']]
# Out:
#           myCal
# 0   1228.274775
# 1     92.564296
# 2    943.601280
# 3    916.084848
# 4    797.710870
# ..          ...
# 95   487.860268
# 96  1870.708840
# 97   343.589253
# 98  3267.137640
# 99  4443.324714
#
# [100 rows x 1 columns]

# %%
df
# Out:
#     Unnamed: 0  CountryName CountryCode  BirthRate  InternetUsers  \
# 0            0    Country_1       CT001     46.605         26.355
# 1            1    Country_2       CT002      6.488         14.267
# 2            2    Country_3       CT003     18.663         50.560
# 3            3    Country_4       CT004     36.708         24.956
# 4            4    Country_5       CT005     29.782         26.785
# ..         ...          ...         ...        ...            ...
# 95          95   Country_96       CT096     19.964         24.437
# 96          96   Country_97       CT097     20.020         93.442
# 97          97   Country_98       CT098      5.971         57.543
# 98          98   Country_99       CT099     35.620         91.722
# 99          99  Country_100       CT100     47.923         92.718
#
#             IncomeGroup        myCal
# 0            Low income  1228.274775
# 1   Upper middle income    92.564296
# 2   Upper middle income   943.601280
# ...

# %%
df = df.drop('myCal',axis=1) #drop() removes 'myCal' axis = 1 means columns and axis = 0 means rows

# %%
df.columns #'myCal' removed
# Out:
# Index(['Unnamed: 0', 'CountryName', 'CountryCode', 'BirthRate',
#        'InternetUsers', 'IncomeGroup'],
#       dtype='object')

# %%
df['InternetUsers']
# Out:
# 0     26.355
# 1     14.267
# 2     50.560
# 3     24.956
# 4     26.785
#        ...
# 95    24.437
# 96    93.442
# 97    57.543
# 98    91.722
# 99    92.718
# Name: InternetUsers, Length: 100, dtype: float64

# %%
df.InternetUsers<2 #We are cheching given condition if its correct true or false
# Out:
# 0     False
# 1     False
# 2     False
# 3     False
# 4     False
#       ...
# 95    False
# 96    False
# 97    False
# 98    False
# 99    False
# Name: InternetUsers, Length: 100, dtype: bool

# %%
Filter = df.InternetUsers<2 #We are cheching given condition if its correct true or false

# %%
Filter
# Out:
# 0     False
# 1     False
# 2     False
# 3     False
# 4     False
#       ...
# 95    False
# 96    False
# 97    False
# 98    False
# 99    False
# Name: InternetUsers, Length: 100, dtype: bool

# %%
df[Filter]
# Out:
#     Unnamed: 0 CountryName CountryCode  BirthRate  InternetUsers  \
# 43          43  Country_44       CT044     11.038          1.041
# 67          67  Country_68       CT068     39.299          1.930
# 82          82  Country_83       CT083     30.929          1.007
#
#             IncomeGroup
# 43  Lower middle income
# 67  Lower middle income
# 82  Upper middle income

# %%
len(df[Filter]) #counts the internetUSers below then 2
# Out:
# 3

# %%
df
# Out:
#     Unnamed: 0  CountryName CountryCode  BirthRate  InternetUsers  \
# 0            0    Country_1       CT001     46.605         26.355
# 1            1    Country_2       CT002      6.488         14.267
# 2            2    Country_3       CT003     18.663         50.560
# 3            3    Country_4       CT004     36.708         24.956
# 4            4    Country_5       CT005     29.782         26.785
# ..         ...          ...         ...        ...            ...
# 95          95   Country_96       CT096     19.964         24.437
# 96          96   Country_97       CT097     20.020         93.442
# 97          97   Country_98       CT098      5.971         57.543
# 98          98   Country_99       CT099     35.620         91.722
# 99          99  Country_100       CT100     47.923         92.718
#
#             IncomeGroup
# 0            Low income
# 1   Upper middle income
# 2   Upper middle income
# 3   Upper middle income
# 4   Lower middle income
# ...

# %%
df.BirthRate>40
# Out:
# 0      True
# 1     False
# 2     False
# 3     False
# 4     False
#       ...
# 95    False
# 96    False
# 97    False
# 98    False
# 99     True
# Name: BirthRate, Length: 100, dtype: bool

# %%
Filter2 = df.BirthRate>40 
Filter2
# Out:
# 0      True
# 1     False
# 2     False
# 3     False
# 4     False
#       ...
# 95    False
# 96    False
# 97    False
# 98    False
# 99     True
# Name: BirthRate, Length: 100, dtype: bool

# %%
df[Filter2]
# Out:
#     Unnamed: 0  CountryName CountryCode  BirthRate  InternetUsers  \
# 0            0    Country_1       CT001     46.605         26.355
# 6            6    Country_7       CT007     46.379         40.695
# 11          11   Country_12       CT012     41.778          6.575
# 12          12   Country_13       CT013     48.419         54.095
# 15          15   Country_16       CT016     45.322         63.490
# 17          17   Country_18       CT018     47.504         92.489
# 23          23   Country_24       CT024     48.380         72.699
# 24          24   Country_25       CT025     42.809         77.402
# 25          25   Country_26       CT026     42.807         61.777
# 26          26   Country_27       CT027     45.609         79.504
# 30          30   Country_31       CT031     41.845         66.406
# 38          38   Country_39       CT039     47.046         40.349
# 45          45   Country_46       CT046     40.878         75.664
# ...

# %%
len(df[Filter2]) #counts the BirthRate below then 40
# Out:
# 30

# %%
df[Filter & Filter2]
# Out:
# Empty DataFrame
# Columns: [Unnamed: 0, CountryName, CountryCode, BirthRate, InternetUsers, IncomeGroup]
# Index: []

# %%
df[df.IncomeGroup == 'High income'] #returns where incomegroup is equals to highincome
# Out:
#     Unnamed: 0 CountryName CountryCode  BirthRate  InternetUsers  IncomeGroup
# 6            6   Country_7       CT007     46.379         40.695  High income
# 10          10  Country_11       CT011     20.871         93.355  High income
# 12          12  Country_13       CT013     48.419         54.095  High income
# 17          17  Country_18       CT018     47.504         92.489  High income
# 21          21  Country_22       CT022     30.248         58.378  High income
# 22          22  Country_23       CT023     38.235         76.039  High income
# 23          23  Country_24       CT024     48.380         72.699  High income
# 26          26  Country_27       CT027     45.609         79.504  High income
# 27          27  Country_28       CT028     36.498         27.015  High income
# 29          29  Country_30       CT030     23.210         14.284  High income
# 31          31  Country_32       CT032     28.991         56.196  High income
# ...

# %%
df.IncomeGroup.unique() #gets the unique categories
# Out:
# array(['Low income', 'Upper middle income', 'Lower middle income',
#        'High income'], dtype=object)

# %%
#How to get  the unique categories
df.IncomeGroup.nunique() #gets number of unique categeries
# Out:
# 4

# %% [markdown]
# **We can Analyse python dataframe or dataset**

# %%
import matplotlib.pyplot as plt #visulaiztion
import seaborn as sns #distribution visualtion (Ststical visualization)

#seaborn are used for advance visualization ex --> distribution plot, line plot

# %matplotlib inline
plt.rcParams['figure.figsize'] = 6,2

import warnings

warnings.filterwarnings('ignore') #os error

# %%
df.head()
# Out:
#    Unnamed: 0 CountryName CountryCode  BirthRate  InternetUsers  \
# 0           0   Country_1       CT001     46.605         26.355
# 1           1   Country_2       CT002      6.488         14.267
# 2           2   Country_3       CT003     18.663         50.560
# 3           3   Country_4       CT004     36.708         24.956
# 4           4   Country_5       CT005     29.782         26.785
#
#            IncomeGroup
# 0           Low income
# 1  Upper middle income
# 2  Upper middle income
# 3  Upper middle income
# 4  Lower middle income

# %%
df['InternetUsers']
# Out:
# 0     26.355
# 1     14.267
# 2     50.560
# 3     24.956
# 4     26.785
#        ...
# 95    24.437
# 96    93.442
# 97    57.543
# 98    91.722
# 99    92.718
# Name: InternetUsers, Length: 100, dtype: float64

# %%
#Distributions :
vis1 = sns.distplot(df['InternetUsers']) #UNIVARIATE ANALYSIS - statistics
#plt.show(vis1)

# %%
vis1 = sns.distplot(df['InternetUsers'],bins=25) #25 bins (bars) was ceated.

# %%
vis2 = sns.displot(df['InternetUsers']) #Distrogram

# %%
#BOX PLOTS:
# %matplotlib inline
plt.rcParams['figure.figsize'] = 8,4
vis4 = sns.boxplot(data = df, x="IncomeGroup",y='BirthRate') #BI - Variate analysis

# %%
vis5=sns.lmplot(data=df,x='InternetUsers',y='BirthRate')

# %%
vis5=sns.lmplot(data=df,x='InternetUsers',y='BirthRate',fit_reg=False)

# %%
vis5=sns.lmplot(data=df,x='InternetUsers',y='BirthRate',hue='IncomeGroup')

# %%
vis5=sns.lmplot(data=df,x='InternetUsers',y='BirthRate',fit_reg=False,hue='IncomeGroup')
