# %% [markdown]
# **pandas is library to deals with dataframe.**

# %% [markdown]
# using help of pandas will can fill missing datain the table

# %% [markdown]
# In pandas column = attributes, feature, variable
# ans rows = records,

# %%
import pandas as pd

# %%
pd.__version__
# Out:
# '2.3.2'

# %%
df=pd.read_csv(r'D:\Data Science\generated_country_data.csv')

# %%
df
# Out:
#     Unnamed: 0  CountryName CountryCode  BirthRate  InternetUsers  \
# 0            0    Country_1       CT001     46.605         26.355
# 1            1    Country_2       CT002      6.488         14.267
# 2            2    Country_3       CT003     18.663         50.560
# 3            3    Country_4       CT004     36.708         24.956
# 4            4    Country_5       CT005     29.782         26.785
# ..         ...          ...         ...        ...            ...
# 95          95   Country_96       CT096     19.964         24.437
# 96          96   Country_97       CT097     20.020         93.442
# 97          97   Country_98       CT098      5.971         57.543
# 98          98   Country_99       CT099     35.620         91.722
# 99          99  Country_100       CT100     47.923         92.718
#
#             IncomeGroup
# 0            Low income
# 1   Upper middle income
# 2   Upper middle income
# 3   Upper middle income
# 4   Lower middle income
# ...

# %%
id(df)
# Out:
# 1874737910912

# %%
type(df)
# Out:
# pandas.core.frame.DataFrame

# %%
len(df)
# Out:
# 100

# %%
df.columns
# Out:
# Index(['Unnamed: 0', 'CountryName', 'CountryCode', 'BirthRate',
#        'InternetUsers', 'IncomeGroup'],
#       dtype='object')

# %%
len(df.columns)
# Out:
# 6

# %%
df.shape
# Out:
# (100, 6)

# %%
df.isnull()
# Out:
#     Unnamed: 0  CountryName  CountryCode  BirthRate  InternetUsers  \
# 0        False        False        False      False          False
# 1        False        False        False      False          False
# 2        False        False        False      False          False
# 3        False        False        False      False          False
# 4        False        False        False      False          False
# ..         ...          ...          ...        ...            ...
# 95       False        False        False      False          False
# 96       False        False        False      False          False
# 97       False        False        False      False          False
# 98       False        False        False      False          False
# 99       False        False        False      False          False
#
#     IncomeGroup
# 0         False
# 1         False
# 2         False
# 3         False
# 4         False
# ..          ...
# 95        False
# 96        False
# ...

# %%
df.isna()
# Out:
#     Unnamed: 0  CountryName  CountryCode  BirthRate  InternetUsers  \
# 0        False        False        False      False          False
# 1        False        False        False      False          False
# 2        False        False        False      False          False
# 3        False        False        False      False          False
# 4        False        False        False      False          False
# ..         ...          ...          ...        ...            ...
# 95       False        False        False      False          False
# 96       False        False        False      False          False
# 97       False        False        False      False          False
# 98       False        False        False      False          False
# 99       False        False        False      False          False
#
#     IncomeGroup
# 0         False
# 1         False
# 2         False
# 3         False
# 4         False
# ..          ...
# 95        False
# 96        False
# ...

# %%
df.isnull().sum()
# Out:
# Unnamed: 0       0
# CountryName      0
# CountryCode      0
# BirthRate        0
# InternetUsers    0
# IncomeGroup      0
# dtype: int64

# %%
df.head() #top 5 rows
# Out:
#    Unnamed: 0 CountryName CountryCode  BirthRate  InternetUsers  \
# 0           0   Country_1       CT001     46.605         26.355
# 1           1   Country_2       CT002      6.488         14.267
# 2           2   Country_3       CT003     18.663         50.560
# 3           3   Country_4       CT004     36.708         24.956
# 4           4   Country_5       CT005     29.782         26.785
#
#            IncomeGroup
# 0           Low income
# 1  Upper middle income
# 2  Upper middle income
# 3  Upper middle income
# 4  Lower middle income

# %%
df.tail() #last 5 rows
# Out:
#     Unnamed: 0  CountryName CountryCode  BirthRate  InternetUsers  \
# 95          95   Country_96       CT096     19.964         24.437
# 96          96   Country_97       CT097     20.020         93.442
# 97          97   Country_98       CT098      5.971         57.543
# 98          98   Country_99       CT099     35.620         91.722
# 99          99  Country_100       CT100     47.923         92.718
#
#             IncomeGroup
# 95  Lower middle income
# 96           Low income
# 97           Low income
# 98           Low income
# 99  Upper middle income

# %%
df.dtypes
# Out:
# Unnamed: 0         int64
# CountryName       object
# CountryCode       object
# BirthRate        float64
# InternetUsers    float64
# IncomeGroup       object
# dtype: object

# %%
df.info() #information
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 100 entries, 0 to 99
# Data columns (total 6 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   Unnamed: 0     100 non-null    int64
#  1   CountryName    100 non-null    object
#  2   CountryCode    100 non-null    object
#  3   BirthRate      100 non-null    float64
#  4   InternetUsers  100 non-null    float64
#  5   IncomeGroup    100 non-null    object
# dtypes: float64(2), int64(1), object(3)
# memory usage: 4.8+ KB

# %% [markdown]
# Slicing in dataframe

# %%
df[:]
# Out:
#     Unnamed: 0  CountryName CountryCode  BirthRate  InternetUsers  \
# 0            0    Country_1       CT001     46.605         26.355
# 1            1    Country_2       CT002      6.488         14.267
# 2            2    Country_3       CT003     18.663         50.560
# 3            3    Country_4       CT004     36.708         24.956
# 4            4    Country_5       CT005     29.782         26.785
# ..         ...          ...         ...        ...            ...
# 95          95   Country_96       CT096     19.964         24.437
# 96          96   Country_97       CT097     20.020         93.442
# 97          97   Country_98       CT098      5.971         57.543
# 98          98   Country_99       CT099     35.620         91.722
# 99          99  Country_100       CT100     47.923         92.718
#
#             IncomeGroup
# 0            Low income
# 1   Upper middle income
# 2   Upper middle income
# 3   Upper middle income
# 4   Lower middle income
# ...

# %%
df[::-1] #returns data in backward order
# Out:
#     Unnamed: 0  CountryName CountryCode  BirthRate  InternetUsers  \
# 99          99  Country_100       CT100     47.923         92.718
# 98          98   Country_99       CT099     35.620         91.722
# 97          97   Country_98       CT098      5.971         57.543
# 96          96   Country_97       CT097     20.020         93.442
# 95          95   Country_96       CT096     19.964         24.437
# ..         ...          ...         ...        ...            ...
# 4            4    Country_5       CT005     29.782         26.785
# 3            3    Country_4       CT004     36.708         24.956
# 2            2    Country_3       CT003     18.663         50.560
# 1            1    Country_2       CT002      6.488         14.267
# 0            0    Country_1       CT001     46.605         26.355
#
#             IncomeGroup
# 99  Upper middle income
# 98           Low income
# 97           Low income
# 96           Low income
# 95  Lower middle income
# ...

# %%
df[:11] # returns from 0 to 10
# Out:
#     Unnamed: 0 CountryName CountryCode  BirthRate  InternetUsers  \
# 0            0   Country_1       CT001     46.605         26.355
# 1            1   Country_2       CT002      6.488         14.267
# 2            2   Country_3       CT003     18.663         50.560
# 3            3   Country_4       CT004     36.708         24.956
# 4            4   Country_5       CT005     29.782         26.785
# 5            5   Country_6       CT006     37.461         71.678
# 6            6   Country_7       CT007     46.379         40.695
# 7            7   Country_8       CT008     18.028          3.256
# 8            8   Country_9       CT009     38.766         78.087
# 9            9  Country_10       CT010     34.794         15.025
# 10          10  Country_11       CT011     20.871         93.355
#
#             IncomeGroup
# 0            Low income
# 1   Upper middle income
# 2   Upper middle income
# 3   Upper middle income
# 4   Lower middle income
# 5            Low income
# ...

# %%
df[0:110:50] # 0 to 110 with 50 step
# Out:
#     Unnamed: 0 CountryName CountryCode  BirthRate  InternetUsers IncomeGroup
# 0            0   Country_1       CT001     46.605         26.355  Low income
# 50          50  Country_51       CT051     30.362         24.433  Low income

# %%
df.columns
# Out:
# Index(['Unnamed: 0', 'CountryName', 'CountryCode', 'BirthRate',
#        'InternetUsers', 'IncomeGroup'],
#       dtype='object')

# %%
df['CountryName'] #Gives only CountryName
# Out:
# 0       Country_1
# 1       Country_2
# 2       Country_3
# 3       Country_4
# 4       Country_5
#          ...
# 95     Country_96
# 96     Country_97
# 97     Country_98
# 98     Country_99
# 99    Country_100
# Name: CountryName, Length: 100, dtype: object

# %%
df[['CountryName','BirthRate']] #Gives only CountryName
# Out:
#     CountryName  BirthRate
# 0     Country_1     46.605
# 1     Country_2      6.488
# 2     Country_3     18.663
# 3     Country_4     36.708
# 4     Country_5     29.782
# ..          ...        ...
# 95   Country_96     19.964
# 96   Country_97     20.020
# 97   Country_98      5.971
# 98   Country_99     35.620
# 99  Country_100     47.923
#
# [100 rows x 2 columns]

# %%
df[['CountryName','BirthRate','CountryCode']] #Gives CountryName and BirthRate and CountryCode
# Out:
#     CountryName  BirthRate CountryCode
# 0     Country_1     46.605       CT001
# 1     Country_2      6.488       CT002
# 2     Country_3     18.663       CT003
# 3     Country_4     36.708       CT004
# 4     Country_5     29.782       CT005
# ..          ...        ...         ...
# 95   Country_96     19.964       CT096
# 96   Country_97     20.020       CT097
# 97   Country_98      5.971       CT098
# 98   Country_99     35.620       CT099
# 99  Country_100     47.923       CT100
#
# [100 rows x 3 columns]

# %%
df.head(3) #returns top 3 values 0 to 3-1 ie 2
# Out:
#    Unnamed: 0 CountryName CountryCode  BirthRate  InternetUsers  \
# 0           0   Country_1       CT001     46.605         26.355
# 1           1   Country_2       CT002      6.488         14.267
# 2           2   Country_3       CT003     18.663         50.560
#
#            IncomeGroup
# 0           Low income
# 1  Upper middle income
# 2  Upper middle income

# %%
df.head(10) #returns top 10 values 0 to 10-1 ie 9
# Out:
#    Unnamed: 0 CountryName CountryCode  BirthRate  InternetUsers  \
# 0           0   Country_1       CT001     46.605         26.355
# 1           1   Country_2       CT002      6.488         14.267
# 2           2   Country_3       CT003     18.663         50.560
# 3           3   Country_4       CT004     36.708         24.956
# 4           4   Country_5       CT005     29.782         26.785
# 5           5   Country_6       CT006     37.461         71.678
# 6           6   Country_7       CT007     46.379         40.695
# 7           7   Country_8       CT008     18.028          3.256
# 8           8   Country_9       CT009     38.766         78.087
# 9           9  Country_10       CT010     34.794         15.025
#
#            IncomeGroup
# 0           Low income
# 1  Upper middle income
# 2  Upper middle income
# 3  Upper middle income
# 4  Lower middle income
# 5           Low income
# 6          High income
# 7           Low income
# 8  Lower middle income
# ...

# %%
df.tail(3) #returns last 3 values
# Out:
#     Unnamed: 0  CountryName CountryCode  BirthRate  InternetUsers  \
# 97          97   Country_98       CT098      5.971         57.543
# 98          98   Country_99       CT099     35.620         91.722
# 99          99  Country_100       CT100     47.923         92.718
#
#             IncomeGroup
# 97           Low income
# 98           Low income
# 99  Upper middle income

# %%
df.tail(10) #returns last 10 values
# Out:
#     Unnamed: 0  CountryName CountryCode  BirthRate  InternetUsers  \
# 90          90   Country_91       CT091     28.743         14.307
# 91          91   Country_92       CT092     38.760         63.334
# 92          92   Country_93       CT093     40.307         61.005
# 93          93   Country_94       CT094     31.181         14.821
# 94          94   Country_95       CT095     31.771         71.886
# 95          95   Country_96       CT096     19.964         24.437
# 96          96   Country_97       CT097     20.020         93.442
# 97          97   Country_98       CT098      5.971         57.543
# 98          98   Country_99       CT099     35.620         91.722
# 99          99  Country_100       CT100     47.923         92.718
#
#             IncomeGroup
# 90  Lower middle income
# 91  Upper middle income
# 92  Lower middle income
# 93           Low income
# 94  Lower middle income
# 95  Lower middle income
# 96           Low income
# 97           Low income
# ...

# %% [markdown]
# Descriptive statistics

# %%
df.describe() 
#By default in pandas describe() only print numerical data and all the values count mean ie. avarage, min, max etc
# Out:
#        Unnamed: 0   BirthRate  InternetUsers
# count  100.000000  100.000000     100.000000
# mean    49.500000   30.711640      49.208800
# std     29.011492   12.637361      29.042642
# min      0.000000    5.646000       1.007000
# 25%     24.750000   20.006000      24.826250
# 50%     49.500000   31.870500      54.882500
# 75%     74.250000   42.052500      74.955250
# max     99.000000   48.680000      93.511000

# %%
df.describe().T # .T means transpose thist means it converts rows to column and column to row
# Out:
#                count      mean        std    min       25%      50%       75%  \
# Unnamed: 0     100.0  49.50000  29.011492  0.000  24.75000  49.5000  74.25000
# BirthRate      100.0  30.71164  12.637361  5.646  20.00600  31.8705  42.05250
# InternetUsers  100.0  49.20880  29.042642  1.007  24.82625  54.8825  74.95525
#
#                   max
# Unnamed: 0     99.000
# BirthRate      48.680
# InternetUsers  93.511

# %% [markdown]
# Descriptive statistics for categirical data

# %%
df.columns
# Out:
# Index(['Unnamed: 0', 'CountryName', 'CountryCode', 'BirthRate',
#        'InternetUsers', 'IncomeGroup'],
#       dtype='object')

# %%
df_cat=df[['CountryName','CountryCode','IncomeGroup']]
df_cat
# Out:
#     CountryName CountryCode          IncomeGroup
# 0     Country_1       CT001           Low income
# 1     Country_2       CT002  Upper middle income
# 2     Country_3       CT003  Upper middle income
# 3     Country_4       CT004  Upper middle income
# 4     Country_5       CT005  Lower middle income
# ..          ...         ...                  ...
# 95   Country_96       CT096  Lower middle income
# 96   Country_97       CT097           Low income
# 97   Country_98       CT098           Low income
# 98   Country_99       CT099           Low income
# 99  Country_100       CT100  Upper middle income
#
# [100 rows x 3 columns]

# %%
df_cat.describe()
# Out:
#        CountryName CountryCode          IncomeGroup
# count          100         100                  100
# unique         100         100                    4
# top      Country_1       CT001  Upper middle income
# freq             1           1                   27
